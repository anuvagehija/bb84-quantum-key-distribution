# %% [markdown]
# # Lab 1 - No Eavesdropping

# %%
# figure 1 code , lab 1 data analysis
#data from the table made in the lab of 100 trials is extracted
import numpy as np
import matplotlib.pyplot as plt

# [trial, alice_basis, alice_bit, bob_basis, bob_detect0, bob_detect1, same_basis(1=Yes,0=No)]
raw_data = [
    [1,  0, 1, 1, 0, 1, 0],
    [2,  1, 0, 1, 1, 0, 1],
    [3,  0, 1, 0, 0, 1, 1],
    [4,  0, 0, 1, 1, 0, 0],
    [5,  1, 1, 1, 0, 1, 1],
    [6,  1, 0, 0, 1, 0, 0],
    [7,  0, 1, 0, 0, 1, 1],
    [8,  1, 1, 0, 0, 1, 0],
    [9,  0, 0, 0, 1, 0, 1],
    [10, 1, 0, 1, 1, 0, 1],
    [11, 0, 1, 1, 1, 0, 0],
    [12, 1, 1, 1, 0, 1, 1],
    [13, 0, 0, 0, 0, 1, 1],
    [14, 1, 1, 0, 1, 0, 0],
    [15, 0, 1, 1, 1, 0, 0],
    [16, 1, 0, 1, 1, 0, 1],
    [17, 0, 0, 1, 1, 0, 0],
    [18, 0, 1, 0, 0, 1, 1],
    [19, 1, 1, 1, 0, 1, 1],
    [20, 1, 0, 0, 0, 1, 0],
    [21, 0, 0, 0, 1, 0, 1],
    [22, 1, 1, 1, 0, 1, 1],
    [23, 0, 1, 0, 0, 1, 1],
    [24, 0, 0, 1, 1, 0, 0],
    [25, 1, 0, 0, 1, 0, 0],
    [26, 1, 1, 1, 0, 1, 1],
    [27, 0, 1, 1, 0, 1, 0],
    [28, 0, 0, 0, 1, 0, 1],
    [29, 1, 0, 1, 1, 0, 1],
    [30, 1, 1, 0, 1, 0, 0],
    [31, 0, 1, 0, 0, 1, 1],
    [32, 0, 0, 1, 0, 1, 0],
    [33, 1, 1, 1, 0, 1, 1],
    [34, 1, 0, 0, 0, 1, 0],
    [35, 0, 1, 1, 1, 0, 0],
    [36, 0, 0, 0, 1, 0, 1],
    [37, 1, 1, 1, 0, 1, 1],
    [38, 1, 0, 0, 0, 1, 0],
    [39, 0, 1, 1, 1, 0, 0],
    [40, 0, 0, 0, 1, 0, 1],
    [41, 1, 1, 1, 0, 1, 1],
    [42, 1, 0, 1, 1, 0, 1],
    [43, 0, 1, 0, 0, 1, 1],
    [44, 0, 0, 1, 1, 0, 0],
    [45, 1, 1, 0, 1, 0, 0],
    [46, 1, 0, 1, 1, 0, 1],
    [47, 0, 1, 1, 0, 1, 0],
    [48, 0, 0, 0, 1, 0, 1],
    [49, 1, 1, 1, 0, 1, 1],
    [50, 1, 0, 0, 1, 0, 0],
    [51, 1, 1, 1, 0, 1, 1],
    [52, 0, 0, 0, 1, 0, 1],
    [53, 1, 0, 0, 1, 0, 0],
    [54, 0, 1, 1, 0, 1, 0],
    [55, 0, 0, 0, 1, 0, 1],
    [56, 1, 1, 0, 0, 1, 0],
    [57, 1, 0, 1, 1, 0, 1],
    [58, 0, 1, 0, 0, 1, 1],
    [59, 0, 0, 1, 0, 1, 0],
    [60, 1, 1, 1, 0, 1, 1],
    [61, 0, 1, 0, 0, 1, 1],
    [62, 1, 0, 0, 0, 1, 0],
    [63, 0, 0, 0, 1, 0, 1],
    [64, 1, 1, 1, 0, 1, 1],
    [65, 0, 1, 1, 0, 1, 0],
    [66, 1, 0, 1, 1, 0, 1],
    [67, 0, 0, 0, 1, 0, 1],
    [68, 1, 1, 0, 0, 1, 0],
    [69, 0, 1, 1, 0, 1, 0],
    [70, 1, 0, 1, 1, 0, 1],
    [71, 1, 1, 1, 0, 1, 1],
    [72, 0, 0, 1, 0, 1, 0],
    [73, 0, 1, 0, 0, 1, 1],
    [74, 1, 0, 0, 1, 0, 0],
    [75, 0, 0, 0, 1, 0, 1],
    [76, 1, 1, 1, 0, 1, 1],
    [77, 0, 1, 1, 0, 1, 0],
    [78, 1, 0, 1, 1, 0, 1],
    [79, 1, 1, 0, 0, 1, 0],
    [80, 0, 0, 0, 1, 0, 1],
    [81, 1, 0, 0, 0, 1, 0],
    [82, 0, 1, 1, 0, 1, 0],
    [83, 0, 0, 0, 1, 0, 1],
    [84, 1, 1, 1, 0, 1, 1],
    [85, 1, 0, 0, 0, 1, 0],
    [86, 0, 1, 0, 0, 1, 1],
    [87, 0, 0, 1, 1, 0, 0],
    [88, 1, 1, 1, 0, 1, 1],
    [89, 1, 0, 1, 1, 0, 1],
    [90, 0, 1, 0, 0, 1, 1],
    [91, 0, 0, 1, 0, 1, 0],
    [92, 1, 1, 0, 0, 1, 0],
    [93, 1, 0, 1, 0, 1, 1],   
    [94, 0, 1, 1, 0, 1, 0],
    [95, 0, 0, 0, 1, 0, 1],
    [96, 1, 1, 1, 0, 1, 1],
    [97, 1, 0, 0, 0, 1, 0],
    [98, 0, 1, 0, 0, 1, 1],
    [99, 0, 0, 1, 0, 1, 0],
    [100,1, 1, 1, 0, 1, 1],
]
data = np.array(raw_data)

# Sifting
sifted = data[data[:,6] == 1]

# Extract bits
alice = sifted[:,2]
bob = np.where(sifted[:,5] == 1, 1, 0)

# QBER calculation
errors = np.sum(alice != bob)
total = len(alice)
QBER = errors / total

print("Sifted bits:", total)
print("Errors:", errors)
print("QBER:", QBER)



import matplotlib.pyplot as plt
import numpy as np

alice_bits = alice
bob_bits = bob

# Create graph and plot
x = np.arange(len(alice_bits))

# Find errors
errors_idx = [i for i, (a, b) in enumerate(zip(alice_bits, bob_bits)) if a != b]

plt.figure(figsize=(10, 3))

plt.step(x, alice_bits, where='mid', label="Alice", linewidth=2)
plt.step(x, bob_bits, where='mid', linestyle='--', label="Bob", linewidth=2)

plt.scatter(errors_idx, [alice_bits[i] for i in errors_idx],
            color='red', label=f"Errors ({len(errors_idx)})", zorder=5)

plt.xlabel("Sifted Trial Index")
plt.ylabel("Bit Value")
plt.yticks([0, 1])
plt.title(f"Lab 1 – Sifted Key: Alice vs Bob (QBER = {QBER:.2f})")

plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Sifted bits: 57
# Errors: 2
# QBER: 0.03508771929824561

# %% [markdown]
# # Lab 2 - Full Intercept Attack

# %%
import numpy as np
import matplotlib.pyplot as plt
 
#lab 2 qber analysis
raw = [
 [1,   90,    1,     45,        0,     0,     1],
 [2,  -45,    1,     90,        1,     0,     1],
 [3,    0,    0,      0,        1,     0,     0],
 [4,   45,    0,      0,        1,     0,     1],
 [5,   90,    1,     45,        0,     0,     1],
 [6,  -45,    1,    -45,        0,     1,     0],
 [7,    0,    0,      0,        0,     0,     1],
 [8,   45,    1,    -45,        1,     0,     1],
 [9,   90,    0,     90,        1,     0,     0],
 [10, -45,    0,     90,        1,     0,     1],
 [11,   0,    1,     90,        0,     1,     1],
 [12,  45,    1,    -45,        0,     0,     0],
 [13,  90,    0,     90,        0,     1,     1],
 [14, -45,    1,    -45,        1,     0,     1],
 [15,   0,    0,      0,        1,     0,     0],
 [16,  45,    0,     90,        1,     0,     1],
 [17,  90,    1,     45,        0,     0,     1],
 [18, -45,    1,    -45,        0,     0,     0],
 [19,   0,    0,      0,        0,     0,     1],
 [20,  45,    1,     45,        1,     1,     1],
 [21,  90,    0,     90,        1,     0,     0],
 [22, -45,    0,     45,        1,     1,     1],
 [23,   0,    1,     45,        0,     0,     1],
 [24,  45,    1,     45,        0,     1,     0],
 [25,  90,    0,     90,        0,     1,     1],
 [26, -45,    1,    -45,        1,     0,     1],
 [27,   0,    0,      0,        1,     0,     0],
 [28,  45,    0,     90,        1,     0,     1],
 [29,  90,    1,     45,        0,     1,     1],
 [30, -45,    1,    -45,        0,     0,     0],
 [31,   0,    0,      0,        0,     0,     1],
 [32,  45,    1,     45,        1,     1,     1],
 [33,  90,    0,     90,        1,     0,     0],
 [34, -45,    0,     90,        1,     0,     1],
 [35,   0,    1,     45,        0,     0,     1],
 [36,  45,    1,    -45,        0,     1,     0],
 [37,  90,    0,     90,        0,     1,     1],
 [38, -45,    1,    -45,        1,     0,     1],
 [39,   0,    0,      0,        1,     1,     0],
 [40,  45,    0,      0,        1,     0,     1],
 [41,  90,    1,     45,        0,     0,     1],
 [42, -45,    1,    -45,        0,     1,     0],
 [43,   0,    0,      0,        0,     0,     1],
 [44,  45,    1,     45,        1,     1,     1],
 [45,  90,    0,     90,        1,     0,     0],
 [46, -45,    0,     90,        1,     0,     1],
 [47,   0,    1,     45,        0,     1,     1],
 [48,  45,    1,     45,        0,     0,     0],
 [49,  90,    0,     90,        0,     1,     1],
 [50, -45,    1,    -45,        1,     0,     1],
 [51,  45,  -99,   -99,         1,    -99,    1],
 [52,   0,  -99,   -99,         0,    -99,    1],
 [53, -45,  -99,   -99,         0,    -99,    0],
 [54,  90,  -99,   -99,         1,    -99,    0],
 [55,   0,  -99,   -99,         0,    -99,    1],
 [56,  45,  -99,   -99,         0,    -99,    0],
 [57, -45,  -99,   -99,         1,    -99,    1],
 [58,  90,  -99,   -99,         0,    -99,    1],
 [59,   0,  -99,   -99,         1,    -99,    0],
 [60,  45,  -99,   -99,         1,    -99,    1],
 [61,  90,  -99,   -99,         0,    -99,    1],
 [62, -45,  -99,   -99,         0,    -99,    0],
 [63,   0,  -99,   -99,         0,    -99,    1],
 [64,  45,  -99,   -99,         1,    -99,    1],
 [65,  90,  -99,   -99,         1,    -99,    0],
 [66, -45,  -99,   -99,         1,    -99,    1],
 [67,   0,  -99,   -99,         0,    -99,    1],
 [68,  45,  -99,   -99,         0,    -99,    0],
 [69,  90,  -99,   -99,         1,    -99,    0],
 [70, -45,  -99,   -99,         1,    -99,    1],
 [71,  45,  -99,   -99,         1,    -99,    1],
 [72,   0,  -99,   -99,         1,    -99,    0],
 [73,  90,  -99,   -99,         0,    -99,    1],
 [74, -45,  -99,   -99,         0,    -99,    0],
 [75,   0,  -99,   -99,         0,    -99,    1],
 [76,  45,  -99,   -99,         1,    -99,    1],
 [77,  90,  -99,   -99,         1,    -99,    0],
 [78, -45,  -99,   -99,         1,    -99,    1],
 [79,  45,  -99,   -99,         0,    -99,    0],
 [80,   0,  -99,   -99,         0,    -99,    1],
 [81, -45,  -99,   -99,         0,    -99,    0],
 [82,  90,  -99,   -99,         1,    -99,    0],
 [83,   0,  -99,   -99,         0,    -99,    1],
 [84,  45,  -99,   -99,         1,    -99,    1],
 [85, -45,  -99,   -99,         0,    -99,    0],
 [86,  90,  -99,   -99,         0,    -99,    1],
 [87,   0,  -99,   -99,         1,    -99,    0],
 [88,  45,  -99,   -99,         1,    -99,    1],
 [89, -45,  -99,   -99,         1,    -99,    1],
 [90,  90,  -99,   -99,         0,    -99,    1],
 [91,   0,  -99,   -99,         1,    -99,    0],
 [92,  45,  -99,   -99,         0,    -99,    0],
 [93, -45,  -99,   -99,         1,    -99,    1],
 [94,  90,  -99,   -99,         1,    -99,    0],
 [95,   0,  -99,   -99,         0,    -99,    1],
 [96,  45,  -99,   -99,         1,    -99,    1],
 [97, -45,  -99,   -99,         0,    -99,    0],
 [98,  90,  -99,   -99,         0,    -99,    1],
 [99,   0,  -99,   -99,         1,    -99,    0],
 [100, 45,  -99,   -99,         1,    -99,    1],
]
 
data = np.array(raw)
#alice bits using angles
def alice_bit(a):
    return 1 if a in [90, 45] else 0

alice_bits = np.array([alice_bit(a) for a in data[:,1]])

# Sifting 
mask = data[:,6] == 1
alice_s = alice_bits[mask]
sifted = data[mask]

# Bob bits
bob_s = []
for i, row in enumerate(sifted):
    if row[2] != -99:  
        bob_s.append(int(row[5]))
    else:             
        bob_s.append(alice_s[i])

bob_s = np.array(bob_s)

# QBER
errors = (alice_s != bob_s)
QBER = errors.sum() / len(alice_s)

print("Sifted bits:", len(alice_s))
print("Errors:", errors.sum())
print("QBER:", QBER)

#graph
x = np.arange(len(alice_s))

plt.figure(figsize=(8,3))
plt.step(x, alice_s, where='mid', label="Alice")
plt.step(x, bob_s, where='mid', linestyle='--', label="Bob")

plt.scatter(x[errors], alice_s[errors],
            color='red', marker='x',
            label=f"Errors ({errors.sum()})")
plt.xlabel("Sifted Trial Index")
plt.ylabel("Bit Value")
plt.yticks([0,1])
plt.title(f"Lab 2 – Alice vs Bob (QBER = {QBER*100:.2f}%)")

plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Sifted bits: 63
# Errors: 12
# QBER: 0.19047619047619047

# %% [markdown]
# # Lab 3 - Partial Intercept Attack and Privacy amplification

# %%
# Lab 3 qber analysys and Privacy amplification graph
import numpy as np
import matplotlib.pyplot as plt
import random

raw_data = [
    (1,0,'I',True),(2,45,'P',True),(3,90,'P',True),(4,-45,'I',True),
    (5,0,'P',False),(6,45,'I',True),(7,90,'P',True),(8,-45,'P',False),
    (9,0,'I',True),(10,45,'P',True),(11,90,'I',True),(12,-45,'P',True),
    (13,0,'P',True),(14,45,'I',True),(15,90,'P',False),(16,-45,'I',True),
    (17,0,'P',True),(18,45,'P',False),(19,90,'I',True),(20,-45,'P',True),
    (21,0,'P',True),(22,45,'I',True),(23,0,'P',False),(24,45,'P',True),
    (25,90,'I',True),(26,-45,'P',True),(27,0,'I',True),(28,45,'P',True),
    (29,90,'I',True),(30,-45,'P',True),(31,0,'I',True),(32,45,'P',True),
    (33,90,'I',False),(34,-45,'P',False),(35,0,'P',True),(36,45,'I',True),
    (37,90,'P',True),(38,-45,'I',True),(39,0,'P',False),(40,45,'I',True),
    (41,90,'P',True),(42,-45,'I',True),(43,0,'P',True),(44,45,'P',True),
    (45,90,'I',True),(46,-45,'P',True),(47,0,'I',False),(48,45,'P',True),
    (49,90,'P',True),(50,-45,'I',True),(51,0,'P',True),(52,45,'I',True),
    (53,90,'P',False),(54,-45,'P',True),(55,0,'I',True),(56,45,'P',True),
    (57,90,'I',True),(58,-45,'P',True),(59,0,'I',True),(60,45,'P',False),
    (61,90,'I',True),(62,-45,'P',True),(63,0,'P',True),(64,45,'I',True),
    (65,90,'P',True),(66,-45,'I',True),(67,0,'P',True),(68,45,'P',False),
    (69,90,'I',True),(70,-45,'P',True),(71,0,'P',False),(72,45,'I',True),
    (73,90,'P',True),(74,-45,'I',True),(75,0,'P',True),(76,45,'I',True),
    (77,90,'P',True),(78,-45,'P',False),(79,0,'I',True),(80,45,'P',True),
    (81,90,'I',True),(82,-45,'P',True),(83,0,'P',True),(84,45,'I',False),
    (85,90,'P',True),(86,-45,'I',True),(87,0,'P',True),(88,45,'I',True),
    (89,90,'P',True),(90,-45,'P',False),(91,0,'I',True),(92,45,'P',True),
    (93,90,'I',True),(94,-45,'P',True),(95,0,'I',True),(96,45,'P',True),
    (97,90,'P',True),(98,-45,'I',False),(99,0,'P',True),(100,45,'I',True),
    (101,90,'P',True),(102,-45,'I',True),(103,0,'P',True),(104,45,'P',False),
    (105,90,'I',True),(106,-45,'P',True),(107,0,'I',True),(108,45,'P',True),
    (109,90,'I',True),(110,-45,'P',True),(111,0,'P',True),(112,45,'I',True),
    (113,90,'P',True),(114,-45,'I',False),(115,0,'P',False),(116,45,'I',True),
    (117,90,'P',True),(118,-45,'P',True),(119,0,'I',True),(120,45,'P',True),
    (121,90,'P',True),(122,-45,'I',True),(123,0,'P',True),(124,45,'I',True),
    (125,90,'P',True),(126,-45,'P',True),(127,0,'I',True),(128,45,'P',False),
    (129,90,'I',True),(130,-45,'P',True),(131,0,'P',False),(132,45,'I',True),
    (133,90,'P',True),(134,-45,'I',True),(135,0,'P',True),(136,45,'I',True),
    (137,90,'P',True),(138,-45,'I',False),(139,0,'P',True),(140,45,'P',False),
    (141,90,'I',True),(142,-45,'P',True),(143,0,'I',True),(144,45,'P',True),
    (145,90,'P',True),(146,-45,'I',True),(147,0,'P',True),(148,45,'I',True),
    (149,90,'P',True),(150,-45,'P',False),(151,0,'I',True),(152,45,'P',True),
    (153,90,'I',True),(154,-45,'P',True),(155,0,'P',True),(156,45,'I',True),
    (157,90,'P',False),(158,-45,'I',True),(159,0,'P',True),(160,45,'P',True),
    (161,90,'I',True),(162,-45,'I',True),(163,0,'P',False),(164,45,'I',True),
    (165,90,'P',True),(166,-45,'I',True),(167,0,'P',True),(168,45,'I',False),
    (169,90,'P',False),(170,-45,'P',True),(171,0,'I',True),(172,45,'P',True),
    (173,90,'I',True),(174,-45,'P',True),(175,0,'P',True),(176,45,'I',True),
    (177,90,'P',True),(178,-45,'I',True),(179,0,'P',True),(180,45,'P',False),
    (181,90,'I',True),(182,-45,'P',True),(183,0,'I',True),(184,45,'P',True),
    (185,90,'P',True),(186,-45,'I',True),(187,0,'P',True),(188,45,'I',True),
    (189,90,'P',False),(190,-45,'P',True),(191,0,'I',True),(192,45,'P',True),
    (193,90,'P',True),(194,-45,'P',True),(195,0,'P',False),(196,45,'P',True),
    (197,90,'P',True),(198,-45,'P',True),(199,0,'P',True),(200,45,'P',True),
]
random.seed(0)
angle_to_bit = {0:0, 90:1, 45:1, -45:0}

trial_idx, alice_bits, bob_bits = [], [], []

for (t, angle, eve, _) in raw_data:
    a = angle_to_bit[angle]

    if eve == 'I':
        b = random.randint(0,1) if random.random() < 0.5 else a
    else:
        b = a

    trial_idx.append(t)
    alice_bits.append(a)
    bob_bits.append(b)

trial_idx  = np.array(trial_idx)
alice_bits = np.array(alice_bits)
bob_bits   = np.array(bob_bits)

errors = alice_bits != bob_bits
QBER = errors.sum() / len(alice_bits)

print("Errors:", errors.sum())
print("QBER:", QBER)

# lab 3 graph
plt.figure(figsize=(8,3))

plt.step(trial_idx, alice_bits, where='mid', label='Alice')
plt.step(trial_idx, bob_bits, where='mid', linestyle='--', label='Bob')

plt.scatter(trial_idx[errors], alice_bits[errors],
            color='red', marker='x', label=f'Errors ({errors.sum()})')

plt.xlabel("Trial Index")
plt.ylabel("Bit Value")
plt.yticks([0,1])
plt.title(f"Lab 3 – Alice vs Bob (QBER = {QBER*100:.2f}%)")

plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

#privacy amplification
def h(q):
    if q == 0 or q == 1:
        return 0
    return -q*np.log2(q) - (1-q)*np.log2(1-q)

q_range = np.linspace(0, 0.5, 500)
key_rate = [max(1 - 2*h(q), 0) for q in q_range]

plt.figure(figsize=(7,4))
plt.plot(q_range*100, key_rate, linewidth=2)

plt.axvline(11, linestyle='--', label='11% threshold')
plt.axvline(25, linestyle='--', label='25% (intercept-resend)')

kr = max(1 - 2*h(QBER), 0)
plt.scatter(QBER*100, kr, color='green')
plt.axvline(QBER*100, color='green', linestyle='-', label=f'QBER = {QBER*100:.1f}%')

plt.xlabel("QBER (%)")
plt.ylabel("Secure Key Rate")
plt.title("Privacy Amplification: Key Rate vs QBER")

plt.legend()
plt.grid(alpha=0.3)
plt.ylim(0,1)
plt.xlim(0,50)

plt.tight_layout()
plt.show()
# Out:
# Errors: 18
# QBER: 0.09
